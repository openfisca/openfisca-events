# %%
import collections
import json
import urllib2

# %%
simulation = dict(
    scenarios = [
        dict(
            test_case = dict(
                familles = [
                    dict(
                        parents = ['ind0', 'ind1'],
                        enfants = ['ind2', 'ind3'],
                        ),
                    ],
                foyers_fiscaux = [
                    dict(
                        declarants = ['ind0', 'ind1'],
                        personnes_a_charge = ['ind2', 'ind3'],
                        ),
                    ],
                individus = [
                    dict(
                        activite = u'Actif occupé',
                        birth = '1970-01-01',
                        id = 'ind0',
                        sali = 35000,
                        statmarit = u'Marié',
                        ),
                    dict(
                        activite = u'Actif occupé',
                        birth = '1970-01-02',
                        id = 'ind1',
                        sali = 35000,
                        statmarit = u'Marié',
                        ),
                    dict(
                        activite = u'Étudiant, élève',
                        birth = '2000-01-03',
                        id = 'ind2',
                        ),
                    dict(
                        activite = u'Étudiant, élève',
                        birth = '2000-01-04',
                        id = 'ind3',
                        ),
                    ],
                menages = [
                    dict(
                        personne_de_reference = 'ind0',
                        conjoint = 'ind1',
                        enfants = ['ind2', 'ind3'],
                        ),
                    ],
                ),
            year = 2013,
            ),
        ],
    )

request = urllib2.Request('http://api.openfisca.fr/api/1/simulate', headers = {
    'Content-Type': 'application/json',
    'User-Agent': 'OpenFisca-Notebook',
    })
try:
    response = urllib2.urlopen(request, json.dumps(simulation))
except urllib2.HTTPError as response:
    print response.read()
    raise
response_dict = json.loads(response.read(), object_pairs_hook = collections.OrderedDict)
print json.dumps(response_dict, indent = 2)
tree = response_dict['value']
# Out:
# {
#   "apiVersion": "1.0",
#   "method": "/api/1/simulate",
#   "params": {
#     "scenarios": [
#       {
#         "test_case": {
#           "foyers_fiscaux": [
#             {
#               "personnes_a_charge": [
#                 "ind2",
#                 "ind3"
#               ],
#               "declarants": [
#                 "ind0",
#                 "ind1"
#               ]
#             }
#           ],
#           "individus": [
#             {
#               "sali": 35000,
#               "activite": "Actif occup\u00e9",
#               "statmarit": "Mari\u00e9",
#               "birth": "1970-01-01"
#             },
#             {
#               "sali": 35000,
#               "activite": "Actif occup\u00e9",
#               "statmarit": "Mari\u00e9",
#               "birth": "1970-01-02"
#             },
#             {
#               "activite": "\u00c9tudiant, \u00e9l\u00e8ve",
#               "birth": "2000-01-03"
#             },
#             {
#               "activite": "\u00c9tudiant, \u00e9l\u00e8ve",
#               "birth": "2000-01-04"
#             }
#           ],
#           "familles": [
#             {
#               "enfants": [
#                 "ind2",
#                 "ind3"
#               ],
#               "parents": [
#                 "ind0",
#                 "ind1"
#               ]
#             }
#           ],
#           "menages": [
#             {
#               "conjoint": "ind1",
#               "enfants": [
#                 "ind2",
#                 "ind3"
#               ],
#               "personne_de_reference": "ind0"
#             }
#           ]
#         },
#         "year": 2013
#       }
#     ]
#   },
#   "url": "http://api.openfisca.fr/api/1/simulate",
#   "value": {
#     "@context": "http://openfisca.fr/contexts/decomposition.jsonld",
#     "@type": "Node",
#     "color": [
#       0,
#       0,
#       255
#     ],
#     "short_name": "Rev. disp.",
#     "code": "revdisp",
#     "type": 2,
#     "name": "Revenu disponible",
#     "children": [
#       {
#         "@type": "Node",
#         "color": [
#           0,
#           155,
#           204
#         ],
#         "short_name": "Rev. nets",
#         "code": "rev_net",
#         "name": "Revenus nets",
#         "children": [
#           {
#             "@type": "Node",
#             "color": [
#               0,
#               155,
#               204
#             ],
#             "short_name": "Rev. travail",
#             "code": "rev_trav",
#             "name": "Revenu du travail",
#             "children": [
#               {
#                 "@type": "Node",
#                 "color": [
#                   0,
#                   138,
#                   201
#                 ],
#                 "short_name": "Sal. nets",
#                 "code": "salnet",
#                 "name": "Salaires nets",
#                 "children": [
#                   {
#                     "@type": "Node",
#                     "color": [
#                       0,
#                       115,
#                       170
#                     ],
#                     "short_name": "Sal. impos.",
#                     "code": "sal",
#                     "name": "Salaires imposables",
#                     "children": [
#                       {
#                         "@type": "Node",
#                         "color": [
#                           0,
#                           99,
#                           143
#                         ],
#                         "short_name": "Sal. bruts",
#                         "code": "salbrut",
#                         "name": "Salaires bruts",
#                         "children": [
#                           {
#                             "@type": "Node",
#                             "color": [
#                               0,
#                               66,
#                               92
#                             ],
#                             "short_name": "Co\u00fbt travail",
#                             "code": "salsuperbrut",
#                             "name": "Salaires super bruts",
#                             "values": [
#                               124209.1171875
#                             ],
#                             "url": "http://www.insee.fr/fr/methodes/default.asp?page=definitions/cout-salarial.htm"
#                           },
#                           {
#                             "@type": "Node",
#                             "color": [
#                               249,
#                               208,
#                               211
#                             ],
#                             "short_name": "Cotsoc pat",
#                             "code": "cotpat",
#                             "name": "Cotisations sociales patronales",
#                             "values": [
#                               -38232.8984375
#                             ],
#                             "url": "http://www.editions-tissot.fr/droit-travail/dictionnaire-droit-travail-definition.aspx?idDef=254&definition=Cotisations+patronales"
#                           },
#                           {
#                             "@type": "Node",
#                             "short_name": "All\u00e8g. sal.",
#                             "code": "alleg_fillon",
#                             "name": "All\u00e8gement sur les bas salaires (Fillon)",
#                             "values": [
#                               0.0
#                             ],
#                             "url": "http://travail-emploi.gouv.fr/informations-pratiques,89/fiches-pratiques,91/remuneration,113/l-allegement-de-charges-patronales,1031.html"
#                           },
#                           {
#                             "@type": "Node",
#                             "short_name": "CICE",
#                             "code": "alleg_cice",
#                             "name": "Cr\u00e9dit d'imp\u00f4t comp\u00e9titivit\u00e9-emploi",
#                             "values": [
#                               0.0
#                             ],
#                             "url": "http://www.economie.gouv.fr/ma-competitivite/quest-que-credit-dimpot-pour-competitivite-et-lemploi"
#                           },
#                           {
#                             "@type": "Node",
#                             "short_name": "Taxe sal.",
#                             "code": "taxes_sal",
#                             "name": "Taxe sur les salaires",
#                             "values": [
#                               0.0
#                             ],
#                             "url": "http://www.impots.gouv.fr/portal/dgi/public/professionnels.impot?espId=2&impot=TS&pageId=prof_ts&sfid=50"
#                           },
#                           {
#                             "@type": "Node",
#                             "short_name": "TEHR",
#                             "code": "tehr",
#                             "name": "Taxe exceptionnelle sur les hauts revenus",
#                             "values": [
#                               0.0
#                             ],
#                             "url": "http://vosdroits.service-public.fr/particuliers/F31130.xhtml"
#                           }
#                         ],
#                         "values": [
#                           85976.21875
#                         ],
#                         "url": "http://www.trader-finance.fr/lexique-finance/definition-lettre-S/Salaire-brut.html"
#                       },
#                       {
#                         "@type": "Node",
#                         "color": [
#                           243,
#                           166,
#                           171
#                         ],
#                         "short_name": "Cotsoc sal",
#                         "code": "cotsal",
#                         "name": "Cotisations sociales salari\u00e9es",
#                         "values": [
#                           -11668.166015625
#                         ],
#                         "url": "http://vosdroits.service-public.fr/particuliers/F2302.xhtml#N100F8"
#                       },
#                       {
#                         "@type": "Node",
#                         "color": [
#                           235,
#                           114,
#                           118
#                         ],
#                         "short_name": "CSG deduc",
#                         "code": "csgsald",
#                         "name": "CSG d\u00e9ductible (salaires)",
#                         "values": [
#                           -4308.05322265625
#                         ],
#                         "url": "http://vosdroits.service-public.fr/particuliers/F2329.xhtml"
#                       },
#                       {
#                         "@type": "Node",
#                         "color": [
#                           0,
#                           115,
#                           170
#                         ],
#                         "short_name": "Heures sup",
#                         "code": "mhsup",
#                         "name": "Heures suppl\u00e9mentaires \u00e9xon\u00e9r\u00e9es",
#                         "values": [
#                           0.0
#                         ],
#                         "url": "http://impotsurlerevenu.org/fonctionnement-de-l-impot/209-heures-supplementaires-exonerees.php"
#                       }
#                     ],
#                     "values": [
#                       69999.99951171875
#                     ],
#                     "url": "http://www.jureka.fr/dico-francais-droit/lettre-s/definition-salaire-imposable"
#                   },
#                   {
#                     "@type": "Node",
#                     "color": [
#                       235,
#                       114,
#                       118
#                     ],
#                     "short_name": "CSG imp. sal.",
#                     "code": "csgsali",
#                     "name": "CSG non d\u00e9ductible (salaires)",
#                     "values": [
#                       -2027.3192138671875
#                     ],
#                     "url": "http://vosdroits.service-public.fr/particuliers/F2329.xhtml"
#                   },
#                   {
#                     "@type": "Node",
#                     "color": [
#                       229,
#                       48,
#                       56
#                     ],
#                     "short_name": "CRDS sal.",
#                     "code": "crdssal",
#                     "name": "CRDS (salaires)",
#                     "values": [
#                       -422.3581848144531
#                     ],
#                     "url": "http://vosdroits.service-public.fr/particuliers/N17580.xhtml"
#                   },
#                   {
#                     "@type": "Node",
#                     "color": [
#                       0,
#                       115,
#                       170
#                     ],
#                     "short_name": "Heures sup",
#                     "code": "hsup",
#                     "name": "Heures suppl\u00e9mentaires",
#                     "values": [
#                       0
#                     ]
#                   }
#                 ],
#                 "values": [
#                   67550.32211303711
#                 ],
#                 "url": "http://www.trader-finance.fr/lexique-finance/definition-lettre-S/Salaire-net.html"
#               },
#               {
#                 "@type": "Node",
#                 "short_name": "Rev. agric.",
#                 "code": "rag",
#                 "name": "Revenus agricoles",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://www.impots.gouv.fr/portal/dgi/public/professionnels.impot?espId=2&impot=BA&pageId=prof_ba&sfid=50"
#               },
#               {
#                 "@type": "Node",
#                 "short_name": "R. ind. comm.",
#                 "code": "ric",
#                 "name": "Revenus industriels et commerciaux",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://www.impots.gouv.fr/portal/dgi/public/professionnels.impot?pageId=prof_bic&espId=2&impot=BIC&sfid=50"
#               },
#               {
#                 "@type": "Node",
#                 "short_name": "R. non comm.",
#                 "code": "rnc",
#                 "name": "Revenus non commerciaux",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://www.impots.gouv.fr/portal/dgi/public/professionnels.impot?espId=2&pageId=prof_bnc&impot=BNC&sfid=50"
#               }
#             ],
#             "values": [
#               67550.32211303711
#             ],
#             "url": "http://fr.wikipedia.org/wiki/Revenu_du_travail"
#           },
#           {
#             "@type": "Node",
#             "color": [
#               97,
#               75,
#               150
#             ],
#             "short_name": "Pensions",
#             "code": "pen",
#             "name": "Pensions",
#             "children": [
#               {
#                 "@type": "Node",
#                 "color": [
#                   136,
#                   120,
#                   178
#                 ],
#                 "short_name": "Ch\u00f4mage net",
#                 "code": "chonet",
#                 "name": "Ch\u00f4mage net",
#                 "children": [
#                   {
#                     "@type": "Node",
#                     "short_name": "Ch\u00f4mage decl.",
#                     "code": "cho",
#                     "name": "Ch\u00f4mage",
#                     "children": [
#                       {
#                         "@type": "Node",
#                         "short_name": "Ch\u00f4mage brut",
#                         "code": "chobrut",
#                         "name": "Ch\u00f4mage brut",
#                         "values": [
#                           0.0
#                         ],
#                         "url": "http://vosdroits.service-public.fr/particuliers/N549.xhtml"
#                       },
#                       {
#                         "@type": "Node",
#                         "color": [
#                           235,
#                           114,
#                           118
#                         ],
#                         "short_name": "CSG d\u00e9d. ch\u00f4m.",
#                         "code": "csgchod",
#                         "name": "CSG d\u00e9ductible (ch\u00f4mage)",
#                         "values": [
#                           0.0
#                         ],
#                         "url": "http://vosdroits.service-public.fr/particuliers/F2329.xhtml"
#                       }
#                     ],
#                     "values": [
#                       0.0
#                     ],
#                     "url": "http://www.insee.fr/fr/methodes/default.asp?page=definitions/chomage.htm"
#                   },
#                   {
#                     "@type": "Node",
#                     "color": [
#                       235,
#                       114,
#                       118
#                     ],
#                     "short_name": "CSG imp. ch\u00f4m.",
#                     "code": "csgchoi",
#                     "name": "CSG non d\u00e9ductible (ch\u00f4mage)",
#                     "values": [
#                       0.0
#                     ],
#                     "url": "http://vosdroits.service-public.fr/particuliers/F2329.xhtml"
#                   },
#                   {
#                     "@type": "Node",
#                     "color": [
#                       229,
#                       48,
#                       56
#                     ],
#                     "short_name": "CRDS ch\u00f4m.",
#                     "code": "crdscho",
#                     "name": "CRDS (ch\u00f4mage)",
#                     "values": [
#                       0.0
#                     ],
#                     "url": "http://www.insee.fr/fr/methodes/default.asp?page=definitions/contrib-remb-dette-sociale.htm"
#                   }
#                 ],
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://vosdroits.service-public.fr/particuliers/N549.xhtml"
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   87,
#                   88,
#                   138
#                 ],
#                 "short_name": "Retraites nettes",
#                 "code": "rstnet",
#                 "name": "Retraites nettes",
#                 "children": [
#                   {
#                     "@type": "Node",
#                     "short_name": "Retr. d\u00e9cl.",
#                     "code": "rst",
#                     "name": "Retraites",
#                     "children": [
#                       {
#                         "@type": "Node",
#                         "short_name": "Retr. brutes",
#                         "code": "rstbrut",
#                         "name": "Retraites brutes",
#                         "values": [
#                           0.0
#                         ],
#                         "url": "http://vosdroits.service-public.fr/particuliers/N20166.xhtml"
#                       },
#                       {
#                         "@type": "Node",
#                         "color": [
#                           235,
#                           114,
#                           118
#                         ],
#                         "short_name": "CSG d\u00e9d. ret.",
#                         "code": "csgrstd",
#                         "name": "CSG d\u00e9ductible (retraite)",
#                         "values": [
#                           0.0
#                         ],
#                         "url": "https://www.lassuranceretraite.fr/cs/Satellite/PUBPrincipale/Retraites/Paiement-Votre-Retraite/Prelevements-Sociaux?packedargs=null"
#                       }
#                     ],
#                     "values": [
#                       0.0
#                     ],
#                     "url": "http://vosdroits.service-public.fr/particuliers/F415.xhtml"
#                   },
#                   {
#                     "@type": "Node",
#                     "color": [
#                       235,
#                       114,
#                       118
#                     ],
#                     "short_name": "CSG imp. pens.",
#                     "code": "csgrsti",
#                     "name": "CSG non d\u00e9ductible (pensions)",
#                     "values": [
#                       0.0
#                     ],
#                     "url": "https://www.lassuranceretraite.fr/cs/Satellite/PUBPrincipale/Retraites/Paiement-Votre-Retraite/Prelevements-Sociaux?packedargs=null"
#                   },
#                   {
#                     "@type": "Node",
#                     "color": [
#                       229,
#                       48,
#                       56
#                     ],
#                     "short_name": "CRDS (pens.)",
#                     "code": "crdsrst",
#                     "name": "CRDS (pensions)",
#                     "values": [
#                       0.0
#                     ],
#                     "url": "http://www.pensions.bercy.gouv.fr/vous-%C3%AAtes-retrait%C3%A9-ou-pensionn%C3%A9/le-calcul-de-ma-pension/les-pr%C3%A9l%C3%A8vements-effectu%C3%A9s-sur-ma-pension"
#                   }
#                 ],
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://vosdroits.service-public.fr/particuliers/N20166.xhtml"
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   136,
#                   120,
#                   178
#                 ],
#                 "short_name": "P. alim. re\u00e7.",
#                 "code": "alr",
#                 "name": "Pensions alimentaires re\u00e7ues",
#                 "values": [
#                   0
#                 ]
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   136,
#                   120,
#                   178
#                 ],
#                 "short_name": "P. alim. vers.",
#                 "code": "alv",
#                 "name": "Pensions alimentaires vers\u00e9e",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://vosdroits.service-public.fr/particuliers/F2.xhtml"
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   125,
#                   185,
#                   86
#                 ],
#                 "short_name": "Rentes viag.",
#                 "code": "rto",
#                 "name": "Rentes viag\u00e8res",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://fr.wikipedia.org/wiki/Rente_viag%C3%A8re"
#               }
#             ],
#             "values": [
#               0.0
#             ],
#             "url": "http://fr.wikipedia.org/wiki/Rente"
#           },
#           {
#             "@type": "Node",
#             "color": [
#               255,
#               222,
#               48
#             ],
#             "short_name": "Rev. cap. net",
#             "code": "rev_cap_net",
#             "name": "Revenus du capital net",
#             "children": [
#               {
#                 "@type": "Node",
#                 "color": [
#                   255,
#                   222,
#                   48
#                 ],
#                 "short_name": "Rev. cap. brut",
#                 "code": "rev_cap_brut",
#                 "name": "Revenus du capital brut",
#                 "children": [
#                   {
#                     "@type": "Node",
#                     "color": [
#                       255,
#                       245,
#                       155
#                     ],
#                     "short_name": "Rev. fonciers",
#                     "code": "fon",
#                     "name": "Revenus fonciers",
#                     "values": [
#                       0.0
#                     ],
#                     "url": "http://impotsurlerevenu.org/definitions/220-revenu-foncier.php"
#                   },
#                   {
#                     "@type": "Node",
#                     "color": [
#                       255,
#                       245,
#                       155
#                     ],
#                     "short_name": "Plus.-values mo.",
#                     "code": "f3vg",
#                     "name": "Plus-values de cessions de valeurs mobili\u00e8res",
#                     "values": [
#                       0
#                     ]
#                   },
#                   {
#                     "@type": "Node",
#                     "color": [
#                       255,
#                       245,
#                       155
#                     ],
#                     "short_name": "Plus.-values immo.",
#                     "code": "f3vz",
#                     "name": "Plus-values immobili\u00e8res",
#                     "values": [
#                       0
#                     ]
#                   },
#                   {
#                     "@type": "Node",
#                     "color": [
#                       255,
#                       239,
#                       103
#                     ],
#                     "short_name": "Rev cap bar",
#                     "code": "rev_cap_bar",
#                     "name": "Revenus du capital soumis au bar\u00e8me",
#                     "values": [
#                       0.0
#                     ],
#                     "url": "http://fr.wikipedia.org/wiki/Revenu#Revenu_du_Capital"
#                   },
#                   {
#                     "@type": "Node",
#                     "color": [
#                       255,
#                       233,
#                       28
#                     ],
#                     "short_name": "Rev cap lib",
#                     "code": "rev_cap_lib",
#                     "name": "Revenus du capital soumis au pr\u00e9l\u00e8vement lib\u00e9ratoire",
#                     "values": [
#                       0.0
#                     ],
#                     "url": "http://fr.wikipedia.org/wiki/Revenu#Revenu_du_Capital"
#                   },
#                   {
#                     "@type": "Node",
#                     "color": [
#                       247,
#                       221,
#                       0
#                     ],
#                     "short_name": "Rev. accesoires",
#                     "code": "rac",
#                     "name": "Revenus accessoires",
#                     "values": [
#                       0.0
#                     ],
#                     "url": "http://vosdroits.service-public.fr/particuliers/F1225.xhtml"
#                   }
#                 ],
#                 "values": [
#                   0.0
#                 ]
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   243,
#                   166,
#                   171
#                 ],
#                 "short_name": "Cotsoc. capital",
#                 "code": "cotsoc_cap",
#                 "name": "Cotisations sociales sur les revenus du capital",
#                 "children": [
#                   {
#                     "@type": "Node",
#                     "color": [
#                       243,
#                       166,
#                       171
#                     ],
#                     "short_name": "Pr. s. cap.",
#                     "code": "prelsoc_cap",
#                     "name": "Pr\u00e9l\u00e8vement social sur les revenus du capital",
#                     "children": [
#                       {
#                         "@type": "Node",
#                         "color": [
#                           243,
#                           166,
#                           171
#                         ],
#                         "short_name": "Pr. s. foncier",
#                         "code": "prelsoc_fon",
#                         "name": "Pr\u00e9l\u00e8vement social sur les revenus fonciers",
#                         "values": [
#                           0.0
#                         ],
#                         "url": "http://www.impots.gouv.fr/portal/dgi/public/particuliers.impot?pageId=part_ctrb_soc&paf_dm=popup&paf_gm=content&typePage=cpr02&sfid=501&espId=1&impot=CS"
#                       },
#                       {
#                         "@type": "Node",
#                         "color": [
#                           243,
#                           166,
#                           171
#                         ],
#                         "short_name": "Prel. soc. p.-v. mo.",
#                         "code": "prelsoc_pv_mo",
#                         "name": "Pr\u00e9l\u00e8vement social sur les plus-values de cessions de valeurs mobili\u00e8res",
#                         "values": [
#                           0.0
#                         ],
#                         "url": "http://www.impots.gouv.fr/portal/dgi/public/particuliers.impot?pageId=part_ctrb_soc&paf_dm=popup&paf_gm=content&typePage=cpr02&sfid=501&espId=1&impot=CS"
#                       },
#                       {
#                         "@type": "Node",
#                         "color": [
#                           243,
#                           166,
#                           171
#                         ],
#                         "short_name": "Prel. soc. p.-v.",
#                         "code": "prelsoc_pv_immo",
#                         "name": "Pr\u00e9l\u00e8vement social sur les plus-values immobili\u00e8res",
#                         "values": [
#                           0.0
#                         ],
#                         "url": "http://www.pap.fr/argent/impots/les-plus-values-immobilieres/a1314/l-imposition-de-la-plus-value-immobiliere"
#                       },
#                       {
#                         "@type": "Node",
#                         "color": [
#                           243,
#                           166,
#                           171
#                         ],
#                         "short_name": "Pr. s. cap. bar.",
#                         "code": "prelsoc_cap_bar",
#                         "name": "Pr\u00e9l\u00e8vement social sur les revenus du capital soumis au bar\u00e8me",
#                         "values": [
#                           0.0
#                         ],
#                         "url": "http://www.impots.gouv.fr/portal/dgi/public/particuliers.impot?pageId=part_ctrb_soc&paf_gm=content&typePage=cpr02&sfid=501&espId=1&impot=CS"
#                       },
#                       {
#                         "@type": "Node",
#                         "color": [
#                           243,
#                           166,
#                           171
#                         ],
#                         "short_name": "Prel. soc. lib.",
#                         "code": "prelsoc_cap_lib",
#                         "name": "Pr\u00e9l\u00e8vement social sur les revenus du capital soumis au pr\u00e9l\u00e8vement lib\u00e9ratoire",
#                         "values": [
#                           0.0
#                         ],
#                         "url": "http://www.impots.gouv.fr/portal/dgi/public/particuliers.impot?pageId=part_ctrb_soc&paf_dm=popup&paf_gm=content&typePage=cpr02&sfid=501&espId=1&impot=CS"
#                       }
#                     ],
#                     "values": [
#                       0.0
#                     ],
#                     "url": "ttp://www.impots.gouv.fr/portal/dgi/public/particuliers.impot?pageId=part_ctrb_soc&paf_dm=popup&paf_gm=content&typePage=cpr02&sfid=501&espId=1&impot=CS"
#                   },
#                   {
#                     "@type": "Node",
#                     "color": [
#                       235,
#                       114,
#                       118
#                     ],
#                     "short_name": "CSG cap.",
#                     "code": "csg_cap",
#                     "name": "CSG des revenus du capital",
#                     "children": [
#                       {
#                         "@type": "Node",
#                         "color": [
#                           235,
#                           114,
#                           118
#                         ],
#                         "short_name": "CSG foncier",
#                         "code": "csg_fon",
#                         "name": "CSG (revenus fonciers)",
#                         "values": [
#                           0.0
#                         ],
#                         "url": "http://fr.wikipedia.org/wiki/Contribution_sociale_g%C3%A9n%C3%A9ralis%C3%A9e"
#                       },
#                       {
#                         "@type": "Node",
#                         "color": [
#                           235,
#                           114,
#                           118
#                         ],
#                         "short_name": "CSG p.-v. mo.",
#                         "code": "csg_pv_mo",
#                         "name": "CSG (plus-values de cessions de valeurs mobili\u00e8res)",
#                         "values": [
#                           0.0
#                         ],
#                         "url": "http://vosdroits.service-public.fr/particuliers/F21618.xhtml"
#                       },
#                       {
#                         "@type": "Node",
#                         "color": [
#                           235,
#                           114,
#                           118
#                         ],
#                         "short_name": "CSG p.-v. immo.",
#                         "code": "csg_pv_immo",
#                         "name": "CSG (plus-values immobili\u00e8res)",
#                         "values": [
#                           0.0
#                         ],
#                         "url": "http://fr.wikipedia.org/wiki/Contribution_sociale_g%C3%A9n%C3%A9ralis%C3%A9e"
#                       },
#                       {
#                         "@type": "Node",
#                         "color": [
#                           235,
#                           114,
#                           118
#                         ],
#                         "short_name": "CSG cap. bar.",
#                         "code": "csg_cap_bar",
#                         "name": "CSG (revenus du capital au bar\u00e8me)",
#                         "values": [
#                           0.0
#                         ],
#                         "url": "http://fr.wikipedia.org/wiki/Contribution_sociale_g%C3%A9n%C3%A9ralis%C3%A9e"
#                       },
#                       {
#                         "@type": "Node",
#                         "color": [
#                           235,
#                           114,
#                           118
#                         ],
#                         "short_name": "CSG cap. lib.",
#                         "code": "csg_cap_lib",
#                         "name": "CSG (revenus du capital soumis au pr\u00e9l\u00e8vement lib\u00e9ratoire)",
#                         "values": [
#                           0.0
#                         ],
#                         "url": "http://fr.wikipedia.org/wiki/Contribution_sociale_g%C3%A9n%C3%A9ralis%C3%A9e"
#                       }
#                     ],
#                     "values": [
#                       0.0
#                     ]
#                   },
#                   {
#                     "@type": "Node",
#                     "color": [
#                       229,
#                       48,
#                       56
#                     ],
#                     "short_name": "CRDS cap.",
#                     "code": "crds_cap",
#                     "name": "CRDS",
#                     "children": [
#                       {
#                         "@type": "Node",
#                         "color": [
#                           229,
#                           48,
#                           56
#                         ],
#                         "short_name": "CRDS foncier",
#                         "code": "crds_fon",
#                         "name": "CRDS (revenus fonciers)",
#                         "values": [
#                           0.0
#                         ],
#                         "url": "http://vosdroits.service-public.fr/particuliers/F2329.xhtml"
#                       },
#                       {
#                         "@type": "Node",
#                         "color": [
#                           229,
#                           48,
#                           56
#                         ],
#                         "short_name": "CRDS p.-v. mo.",
#                         "code": "crds_pv_mo",
#                         "name": "CRDS (plus-values de cessions de valeurs mobili\u00e8res)",
#                         "values": [
#                           0.0
#                         ],
#                         "url": "http://fr.wikipedia.org/wiki/Contribution_pour_le_remboursement_de_la_dette_sociale"
#                       },
#                       {
#                         "@type": "Node",
#                         "color": [
#                           229,
#                           48,
#                           56
#                         ],
#                         "short_name": "CRDS p.-v. immo.",
#                         "code": "crds_pv_immo",
#                         "name": "CRDS (plus-values immobili\u00e8res)",
#                         "values": [
#                           0.0
#                         ],
#                         "url": "http://fr.wikipedia.org/wiki/Contribution_pour_le_remboursement_de_la_dette_sociale"
#                       },
#                       {
#                         "@type": "Node",
#                         "color": [
#                           229,
#                           48,
#                           56
#                         ],
#                         "short_name": "CRDS cap. bar.",
#                         "code": "crds_cap_bar",
#                         "name": "CRDS (revenus du capital au bar\u00e8me)",
#                         "values": [
#                           0.0
#                         ],
#                         "url": "http://fr.wikipedia.org/wiki/Contribution_pour_le_remboursement_de_la_dette_sociale"
#                       },
#                       {
#                         "@type": "Node",
#                         "color": [
#                           229,
#                           48,
#                           56
#                         ],
#                         "short_name": "CRDS cap. lib.",
#                         "code": "crds_cap_lib",
#                         "name": "CRDS (revenus du capital soumis au pr\u00e9l\u00e8vement lib\u00e9ratoire)",
#                         "values": [
#                           0.0
#                         ],
#                         "url": "http://fr.wikipedia.org/wiki/Contribution_pour_le_remboursement_de_la_dette_sociale"
#                       }
#                     ],
#                     "values": [
#                       0.0
#                     ]
#                   }
#                 ],
#                 "values": [
#                   0.0
#                 ]
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   232,
#                   79,
#                   95
#                 ],
#                 "short_name": "Pr\u00e9l. lib\u00e9rat.",
#                 "code": "imp_lib",
#                 "name": "Pr\u00e9l\u00e8vement lib\u00e9ratoire sur les revenus du patrimoine",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://www.impots.gouv.fr/portal/dgi/public/particuliers.impot?pageId=part_ctrb_soc&paf_dm=popup&paf_gm=content&typePage=cpr02&sfid=501&espId=1&impot=CS"
#               }
#             ],
#             "values": [
#               0.0
#             ]
#           }
#         ],
#         "comment": "TODO: change color",
#         "values": [
#           67550.32211303711
#         ]
#       },
#       {
#         "@type": "Node",
#         "color": [
#           232,
#           79,
#           95
#         ],
#         "short_name": "IR (LPS)",
#         "code": "ir_lps",
#         "name": "Imp\u00f4t sur le revenu (Landais, Piketty, Saez)",
#         "values": [
#           0.0
#         ],
#         "url": "http://www.impots.gouv.fr/portal/dgi/public/particuliers.impot?pageId=part_impot_revenu&espId=1&impot=IR&sfid=50"
#       },
#       {
#         "@type": "Node",
#         "color": [
#           255,
#           102,
#           63
#         ],
#         "short_name": "Prest. soc.",
#         "code": "psoc",
#         "name": "Prestations sociales",
#         "children": [
#           {
#             "@type": "Node",
#             "color": [
#               83,
#               170,
#               49
#             ],
#             "short_name": "Prest. fam.",
#             "code": "pfam",
#             "name": "Prestations familiales",
#             "children": [
#               {
#                 "@type": "Node",
#                 "color": [
#                   181,
#                   213,
#                   154
#                 ],
#                 "short_name": "Alloc. fam.",
#                 "code": "af",
#                 "name": "Allocations familiales",
#                 "values": [
#                   1532.1600341796875
#                 ],
#                 "url": "https://www.caf.fr/aides-et-services/s-informer-sur-les-aides/petite-enfance/les-allocations-familiales-af-0"
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   125,
#                   185,
#                   86
#                 ],
#                 "short_name": "Compl. fam.",
#                 "code": "cf",
#                 "name": "Compl\u00e9ment familial",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://vosdroits.service-public.fr/particuliers/F13214.xhtml"
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   91,
#                   172,
#                   38
#                 ],
#                 "short_name": "ARS",
#                 "code": "ars",
#                 "name": "Allocation de rentr\u00e9e scolaire",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://vosdroits.service-public.fr/particuliers/F1878.xhtml"
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   80,
#                   160,
#                   38
#                 ],
#                 "short_name": "AEEH",
#                 "code": "aeeh",
#                 "name": "Allocation d'\u00e9ducation de l'enfant handicap\u00e9",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://vosdroits.service-public.fr/particuliers/N14808.xhtml"
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   77,
#                   144,
#                   34
#                 ],
#                 "short_name": "PAJE",
#                 "code": "paje",
#                 "name": "Prestation d'accueil du jeune enfant",
#                 "children": [
#                   {
#                     "@type": "Node",
#                     "short_name": "PAJE",
#                     "code": "paje_base",
#                     "name": "Paje - Allocation de base",
#                     "values": [
#                       0.0
#                     ],
#                     "url": "http://vosdroits.service-public.fr/particuliers/F2552.xhtml"
#                   },
#                   {
#                     "@type": "Node",
#                     "short_name": "Prime naiss.",
#                     "code": "paje_nais",
#                     "name": "Paje - Prime de naissance",
#                     "values": [
#                       0.0
#                     ],
#                     "url": "http://vosdroits.service-public.fr/particuliers/F2550.xhtml"
#                   },
#                   {
#                     "@type": "Node",
#                     "short_name": "CLCA",
#                     "code": "paje_clca",
#                     "name": "Paje - Compl\u00e9ment de libre choix d'activit\u00e9",
#                     "values": [
#                       0.0
#                     ],
#                     "url": "http://vosdroits.service-public.fr/particuliers/F313.xhtml"
#                   },
#                   {
#                     "@type": "Node",
#                     "short_name": "COLCA",
#                     "code": "paje_colca",
#                     "name": "Paje - Compl\u00e9ment optionnel de libre choix d'activit\u00e9",
#                     "values": [
#                       0.0
#                     ],
#                     "url": "http://vosdroits.service-public.fr/particuliers/F15110.xhtml"
#                   },
#                   {
#                     "@type": "Node",
#                     "short_name": "CLCMG",
#                     "code": "paje_clmg",
#                     "name": "Paje - Compl\u00e9ment de libre choix du mode de garde",
#                     "values": [
#                       0.0
#                     ],
#                     "url": "http://www.caf.fr/aides-et-services/s-informer-sur-les-aides/petite-enfance/le-complement-de-libre-choix-du-mode-de-garde"
#                   }
#                 ],
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://www.caf.fr/aides-et-services/s-informer-sur-les-aides/petite-enfance/la-prestation-d-accueil-du-jeune-enfant-paje-0"
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   77,
#                   144,
#                   34
#                 ],
#                 "short_name": "ASF",
#                 "code": "asf",
#                 "name": "Allocation de soutien familial",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://vosdroits.service-public.fr/particuliers/F815.xhtml"
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   229,
#                   48,
#                   56
#                 ],
#                 "short_name": "CRDS fam.",
#                 "code": "crds_pfam",
#                 "name": "CRDS (prestations familiales)",
#                 "values": [
#                   -7.660799980163574
#                 ],
#                 "url": "http://www.cleiss.fr/docs/regimes/regime_francea1.html"
#               }
#             ],
#             "values": [
#               1524.499234199524
#             ],
#             "url": "http://www.social-sante.gouv.fr/informations-pratiques,89/fiches-pratiques,91/prestations-familiales,1885/les-prestations-familiales,12626.html"
#           },
#           {
#             "@type": "Node",
#             "color": [
#               240,
#               138,
#               76
#             ],
#             "short_name": "Min. sociaux",
#             "code": "mini",
#             "name": "Minima sociaux",
#             "children": [
#               {
#                 "@type": "Node",
#                 "color": [
#                   249,
#                   193,
#                   148
#                 ],
#                 "short_name": "ASPA",
#                 "code": "aspa",
#                 "name": "Allocation de solidarit\u00e9 aux personnes ag\u00e9es",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://vosdroits.service-public.fr/particuliers/F16871.xhtml"
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   244,
#                   160,
#                   80
#                 ],
#                 "short_name": "AAH",
#                 "code": "aah",
#                 "name": "Allocation adulte handicap\u00e9",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://vosdroits.service-public.fr/particuliers/N12230.xhtml"
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   244,
#                   160,
#                   80
#                 ],
#                 "short_name": "CAAH",
#                 "code": "caah",
#                 "name": "Compl\u00e9ment de l'allocation adulte handicap\u00e9",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://vosdroits.service-public.fr/particuliers/N12230.xhtml"
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   244,
#                   160,
#                   80
#                 ],
#                 "short_name": "ASI",
#                 "code": "asi",
#                 "name": "Allocation suppl\u00e9mentaire d'invalidit\u00e9",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://vosdroits.service-public.fr/particuliers/F16940.xhtml"
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   239,
#                   130,
#                   19
#                 ],
#                 "short_name": "RSA",
#                 "code": "rsa",
#                 "name": "Revenu de solidarit\u00e9 active",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://vosdroits.service-public.fr/particuliers/N19775.xhtml"
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   239,
#                   130,
#                   19
#                 ],
#                 "short_name": "PSA",
#                 "code": "psa",
#                 "name": "Prime de solidarit\u00e9 active",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://www.service-public.fr/actualites/001077.html"
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   237,
#                   119,
#                   3
#                 ],
#                 "short_name": "AEFA",
#                 "code": "aefa",
#                 "name": "Aide exceptionelle de fin d'ann\u00e9e",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://www.pole-emploi.fr/candidat/aide-exceptionnelle-de-fin-d-annee-dite-prime-de-noel--@/suarticle.jspz?id=70996"
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   208,
#                   112,
#                   4
#                 ],
#                 "short_name": "API",
#                 "code": "api",
#                 "name": "Allocation parent isol\u00e9",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://fr.wikipedia.org/wiki/Allocation_de_parent_isol%C3%A9"
#               }
#             ],
#             "values": [
#               0.0
#             ],
#             "url": "http://fr.wikipedia.org/wiki/Minima_sociaux"
#           },
#           {
#             "@type": "Node",
#             "color": [
#               255,
#               222,
#               48
#             ],
#             "short_name": "Prest. logement",
#             "code": "logt",
#             "name": "Prestations logement",
#             "children": [
#               {
#                 "@type": "Node",
#                 "color": [
#                   255,
#                   245,
#                   155
#                 ],
#                 "short_name": "APL",
#                 "code": "apl",
#                 "name": "Aide personalis\u00e9e au logement",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://vosdroits.service-public.fr/particuliers/F12006.xhtml"
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   255,
#                   239,
#                   103
#                 ],
#                 "short_name": "ALS",
#                 "code": "als",
#                 "name": "Allocation logement social",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://vosdroits.service-public.fr/particuliers/F1280.xhtml"
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   255,
#                   233,
#                   28
#                 ],
#                 "short_name": "ALF",
#                 "code": "alf",
#                 "name": "Allocation de logement familiale",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://vosdroits.service-public.fr/particuliers/F13132.xhtml"
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   247,
#                   221,
#                   0
#                 ],
#                 "short_name": "AL \u00e9tudiant",
#                 "code": "alset",
#                 "name": "Allocation logement \u00e9tudiant",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "https://www.caf.fr/actualites/2012/etudiants-tout-savoir-sur-les-aides-au-logement"
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   229,
#                   48,
#                   56
#                 ],
#                 "short_name": "CRDS log.",
#                 "code": "crds_lgtm",
#                 "name": "CRDS (allocation logement)",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://vosdroits.service-public.fr/particuliers/F17585.xhtml"
#               }
#             ],
#             "values": [
#               0.0
#             ],
#             "url": "http://vosdroits.service-public.fr/particuliers/N20360.xhtml"
#           }
#         ],
#         "values": [
#           1524.499234199524
#         ],
#         "url": "http://fr.wikipedia.org/wiki/Prestation_sociale"
#       },
#       {
#         "@type": "Node",
#         "color": [
#           182,
#           34,
#           131
#         ],
#         "short_name": "PPE",
#         "code": "ppe",
#         "name": "Prime pour l'emploi",
#         "values": [
#           0.0
#         ],
#         "url": "http://vosdroits.service-public.fr/particuliers/F2882.xhtml"
#       },
#       {
#         "@type": "Node",
#         "color": [
#           232,
#           79,
#           95
#         ],
#         "short_name": "Imp\u00f4ts directs",
#         "code": "impo",
#         "name": "Imp\u00f4ts directs",
#         "children": [
#           {
#             "@type": "Node",
#             "color": [
#               232,
#               79,
#               95
#             ],
#             "short_name": "IRPP",
#             "code": "irpp",
#             "name": "Imp\u00f4t sur le revenu",
#             "values": [
#               -4770.47998046875
#             ],
#             "url": "http://www.impots.gouv.fr/portal/dgi/public/particuliers.impot?pageId=part_impot_revenu&espId=1&impot=IR&sfid=50"
#           },
#           {
#             "@type": "Node",
#             "color": [
#               232,
#               79,
#               95
#             ],
#             "short_name": "IR immo.",
#             "code": "ir_pv_immo",
#             "name": "Imp\u00f4t sur le revenu aff\u00e9rent \u00e0 la plus-value immobili\u00e8re",
#             "values": [
#               0.0
#             ],
#             "url": "http://www.impots.gouv.fr/portal/dgi/public/popup?espId=1&typePage=cpr02&docOid=documentstandard_2157"
#           },
#           {
#             "@type": "Node",
#             "color": [
#               182,
#               34,
#               131
#             ],
#             "short_name": "ISF net",
#             "code": "isf net",
#             "name": "ISF net",
#             "children": [
#               {
#                 "@type": "Node",
#                 "color": [
#                   232,
#                   79,
#                   95
#                 ],
#                 "short_name": "ISF",
#                 "code": "isf_tot",
#                 "name": "Imp\u00f4t de solidarit\u00e9 sur la fortune",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://www.impots.gouv.fr/portal/dgi/public/particuliers.impot?pageId=part_isf&espId=1&impot=ISF&sfid=50"
#               },
#               {
#                 "@type": "Node",
#                 "color": [
#                   182,
#                   34,
#                   131
#                 ],
#                 "short_name": "Bouclier fiscal",
#                 "code": "bouclier_fiscal",
#                 "name": "Bouclier fiscal",
#                 "values": [
#                   0.0
#                 ],
#                 "url": "http://fr.wikipedia.org/wiki/Bouclier_fiscal"
#               }
#             ],
#             "values": [
#               0.0
#             ]
#           },
#           {
#             "@type": "Node",
#             "color": [
#               232,
#               79,
#               95
#             ],
#             "short_name": "TH",
#             "code": "tax_hab",
#             "name": "Taxe d'habitation",
#             "values": [
#               0.0
#             ],
#             "url": "http://www.impots.gouv.fr/portal/dgi/public/particuliers.impot?espId=1&pageId=part_taxe_habitation&impot=TH&sfid=50"
#           }
#         ],
#         "values": [
#           -4770.47998046875
#         ],
#         "url": "http://fr.wikipedia.org/wiki/Imp%C3%B4t_direct"
#       }
#     ],
#     "comment": "TODO: missing indemnite_residence and sft",
#     "values": [
#       64304.34136676788
#     ],
#     "url": "http://fr.wikipedia.org/wiki/Revenu_disponible"
#   }
# }

# %%
def any(iterator):
    for item in iterator:
        if item:
            return True
    return False

def iter_columns_from_tree(node, base_values = None):
    children = node.get('children')
    if children:
        child_base_values = base_values
        for child in children:
            for column in iter_columns_from_tree(child, base_values = child_base_values):
                yield column
            if child_base_values is None:
                child_base_values = child['values']
            else:
                child_base_values = [
                    base_value + value
                    for base_value, value in zip(child_base_values, child['values'])
                    ]

    if any(value != 0 for value in node['values']):
        column = dict(
            base_values = base_values or [0] * len(node['values']),
            code = node['code'],
            )
        column.update(node)
        yield column

# %%
for column_index, column in enumerate(iter_columns_from_tree(tree)):
    print u'{:40s} | {}'.format(column['name'], ' | '.join('{:6.0f}'.format(value) for value in column['values']))
# Out:
# Salaires super bruts                     | 124209
# Cotisations sociales patronales          | -38233
# Salaires bruts                           |  85976
# Cotisations sociales salariées           | -11668
# CSG déductible (salaires)                |  -4308
# Salaires imposables                      |  70000
# CSG non déductible (salaires)            |  -2027
# CRDS (salaires)                          |   -422
# Salaires nets                            |  67550
# Revenu du travail                        |  67550
# Revenus nets                             |  67550
# Allocations familiales                   |   1532
# CRDS (prestations familiales)            |     -8
# Prestations familiales                   |   1524
# Prestations sociales                     |   1524
# Impôt sur le revenu                      |  -4770
# Impôts directs                           |  -4770
# Revenu disponible                        |  64304

# %%
from __future__ import division

from matplotlib.patches import FancyArrow

bar_width = 0.8
title = u'Revenu annuel'
value_index = 0
xlabel = u'Prélèvements et prestations sociales'
ylabel = u'Montant en €'

figure = pyplot.figure(figsize = (15, 9), dpi = 100)
ax = figure.add_subplot(111)
ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax.set_xscale('linear')
ax.set_yscale('linear')
#ax.set_xlim(*xlim)
#ax.set_ylim(*ylim)
#ax.hold(False)

names = []
for column_index, column in enumerate(iter_columns_from_tree(tree)):
    r, g, b = column['color']
    base_value = column['base_values'][0]
    value = column['values'][0]
    arrow = FancyArrow(column_index + bar_width / 2, base_value , 0, value, width = bar_width,
        fc = (r / 255, g / 255, b / 255), linewidth = 0.5, edgecolor = 'black', label = column['name'],
        picker = True, length_includes_head = True, head_width = bar_width, head_length = abs(value / 15))
    ax.add_patch(arrow)
    rounded_value = round(value)
    ax.text(column_index + bar_width / 2, max(base_value, value) + 1, str(int(rounded_value)), horizontalalignment = 'center',
        verticalalignment = 'bottom', color = 'black' if rounded_value >= 0 else 'red', weight = 'bold')
    names.append(column['short_name'])

xlim = (-bar_width / 2, len(names) - 1 + bar_width * 1.5)
#ax.hold(True)
ax.plot(xlim, [0, 0], color = 'black')
ax.set_xticklabels(names, rotation = '45')
ax.set_xticks(np.arange(len(names)) + bar_width / 2)
ax.set_xlim(xlim)
#ticks = ax.get_xticklines()
#for tick in ticks:
#    tick.set_visible(False)

#m, M = ax.get_ylim()
#ax.set_ylim((m, 1.05*M))
# Out:
# (-0.4, 18.2)

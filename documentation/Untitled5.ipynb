# %%
x = [1, 2, 3]
y = [4, 5, 6]
z = y
y = x
x = z

x = [1, 2, 3] # a different [1, 2, 3] list!
y = x
x.append(4)


y.append(5)
z = [1, 2, 3, 4, 5] # a different list!
x.append(6)
y.append(7)
y = "hello"


def foo(lst):
    lst.append("hello")
    bar(lst)

def bar(myLst):
    print(myLst)

foo(x)
foo(z)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 'hello']
# [1, 2, 3, 4, 5, 'hello']

# %%
n
import pdb; pdb.set_trace()
# Object-oriented programming intro
# Adapted from MIT 6.01 course notes (Section 3.5)
# http://mit.edu/6.01/mercurial/spring10/www/handouts/readings.pdf

class Staff601:
    course = '6.01'
    building = 34
    room = 501

    def salutation(self):
        return self.role + ' ' + self.name

pat = Staff601()
print(pat.course)

pat.name = 'Pat'
pat.age = 60
pat.role = 'Professor'

print(pat.building)
pat.building = 32
print(pat.building)

print(pat.salutation())
print(Staff601.salutation(pat))
# Out:
# --Return--
# > <ipython-input-1-664d3dd78222>(1)<module>()->None
# -> import pdb; pdb.set_trace()
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3069)run_code()
# -> sys.excepthook = old_excepthook
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3085)run_code()
# -> outflag = 0
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3086)run_code()
# -> return outflag
# (Pdb) n
# --Return--
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3086)run_code()->0
# -> return outflag
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3003)run_ast_nodes()
# -> for i, node in enumerate(to_run_exec):
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3004)run_ast_nodes()
# -> mod = ast.Module([node])
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3005)run_ast_nodes()
# -> code = compiler(mod, cell_name, "exec")
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3006)run_ast_nodes()
# -> if self.run_code(code, result):
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3003)run_ast_nodes()
# -> for i, node in enumerate(to_run_exec):
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3004)run_ast_nodes()
# -> mod = ast.Module([node])
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3005)run_ast_nodes()
# -> code = compiler(mod, cell_name, "exec")
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3006)run_ast_nodes()
# -> if self.run_code(code, result):
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3003)run_ast_nodes()
# -> for i, node in enumerate(to_run_exec):
# (Pdb)
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3004)run_ast_nodes()
# -> mod = ast.Module([node])
# (Pdb)
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3005)run_ast_nodes()
# -> code = compiler(mod, cell_name, "exec")
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3006)run_ast_nodes()
# -> if self.run_code(code, result):
# (Pdb) n
# 6.01
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3003)run_ast_nodes()
# -> for i, node in enumerate(to_run_exec):
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3004)run_ast_nodes()
# -> mod = ast.Module([node])
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3005)run_ast_nodes()
# -> code = compiler(mod, cell_name, "exec")
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3006)run_ast_nodes()
# -> if self.run_code(code, result):
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3003)run_ast_nodes()
# -> for i, node in enumerate(to_run_exec):
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3004)run_ast_nodes()
# -> mod = ast.Module([node])
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3005)run_ast_nodes()
# -> code = compiler(mod, cell_name, "exec")
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3006)run_ast_nodes()
# -> if self.run_code(code, result):
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3003)run_ast_nodes()
# -> for i, node in enumerate(to_run_exec):
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3004)run_ast_nodes()
# -> mod = ast.Module([node])
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3005)run_ast_nodes()
# -> code = compiler(mod, cell_name, "exec")
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3006)run_ast_nodes()
# -> if self.run_code(code, result):
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3003)run_ast_nodes()
# -> for i, node in enumerate(to_run_exec):
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3004)run_ast_nodes()
# -> mod = ast.Module([node])
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3005)run_ast_nodes()
# -> code = compiler(mod, cell_name, "exec")
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3006)run_ast_nodes()
# -> if self.run_code(code, result):
# (Pdb) n
# 34
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3003)run_ast_nodes()
# -> for i, node in enumerate(to_run_exec):
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3004)run_ast_nodes()
# -> mod = ast.Module([node])
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3005)run_ast_nodes()
# -> code = compiler(mod, cell_name, "exec")
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3006)run_ast_nodes()
# -> if self.run_code(code, result):
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3003)run_ast_nodes()
# -> for i, node in enumerate(to_run_exec):
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3004)run_ast_nodes()
# -> mod = ast.Module([node])
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3005)run_ast_nodes()
# -> code = compiler(mod, cell_name, "exec")
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3006)run_ast_nodes()
# -> if self.run_code(code, result):
# (Pdb) n
# 32
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3003)run_ast_nodes()
# -> for i, node in enumerate(to_run_exec):
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3004)run_ast_nodes()
# -> mod = ast.Module([node])
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3005)run_ast_nodes()
# -> code = compiler(mod, cell_name, "exec")
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3006)run_ast_nodes()
# -> if self.run_code(code, result):
# (Pdb) n
# Professor Pat
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3003)run_ast_nodes()
# -> for i, node in enumerate(to_run_exec):
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3004)run_ast_nodes()
# -> mod = ast.Module([node])
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3005)run_ast_nodes()
# -> code = compiler(mod, cell_name, "exec")
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3006)run_ast_nodes()
# -> if self.run_code(code, result):
# (Pdb) n
# Professor Pat
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3003)run_ast_nodes()
# -> for i, node in enumerate(to_run_exec):
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3009)run_ast_nodes()
# -> for i, node in enumerate(to_run_interactive):
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3016)run_ast_nodes()
# -> if softspace(sys.stdout, 0):
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3034)run_ast_nodes()
# -> return False
# (Pdb) n
# --Return--
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(3034)run_ast_nodes()->False
# -> return False
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(2906)run_cell()
# -> self.displayhook.exec_result = None
# (Pdb) n
# > /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py(2908)run_cell()
# -> self.events.trigger('post_execute')

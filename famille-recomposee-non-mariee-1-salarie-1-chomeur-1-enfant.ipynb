# %%
from __future__ import division

import collections
import copy
import json
import urllib2

# %%
base_scenario = dict(
    familles = [
        dict(
            parents = ['ind0', 'ind1'],
            enfants = ['ind2'],
            ),
        ],
    foyers_fiscaux = [
        dict(
            declarants = ['ind0'],
            personnes_a_charge = ['ind2'],
            ),
        dict(
            declarants = ['ind1'],
            ),
        ],
    individus = [
        dict(
            birth = '1970-01-01',
            id = 'ind0',
            sali = 16000,
            ),
        dict(
            birth = '1970-01-02',
            id = 'ind1',
            choi = 12500,
            ),
        dict(
            birth = '2000-01-03',
            id = 'ind2',
            ),
        ],
    legislation_url = 'http://api.openfisca.fr/api/1/default-legislation',
    menages = [
        dict(
            personne_de_reference = 'ind0',
            conjoint = 'ind1',
            enfants = ['ind2'],
            ),
        ],
    )
years = [2013]

# %%
scenarios = []
for year in years:
    scenario = copy.deepcopy(base_scenario)
    scenario['year'] = year
    scenarios.append(scenario)

simulation = dict(
    scenarios = scenarios,
    )

request = urllib2.Request('http://api.openfisca.fr/api/1/simulate', headers = {
    'Content-Type': 'application/json',
    'User-Agent': 'OpenFisca-Notebook',
    })
try:
    response = urllib2.urlopen(request, json.dumps(simulation))
except urllib2.HTTPError as response:
    print response.read()
    raise
response_dict = json.loads(response.read(), object_pairs_hook = collections.OrderedDict)
trees = response_dict['value']

# %%
def iter_columns_from_tree(node, base_value = 0, code = None):
    children = node.get('children')
    if children:
        child_base_value = base_value
        for child_code, child in children.iteritems():
            for column in iter_columns_from_tree(child, base_value = child_base_value, code = child_code):
                yield column
            child_base_value += child['values'][value_index]

    value = node['values'][value_index]
    if value != 0 and code is not None:
        column = dict(
            base_value = base_value,
            code = code,
            value = value,
            )
        column.update(node)
        yield column

# %%
value_index = 0
tree = trees[0]
for column_index, column in enumerate(iter_columns_from_tree(tree)):
    base_value = column['base_value']
    value = column['value']
    print u'{:20s} | {:10.2f} | {:10.2f}'.format(column['name'], column['base_value'], column['value'])
# Out:
# Coût travail         |       0.00 |   24072.83
# Cotsoc pat           |   24072.83 |   -8785.40
# Allèg. sal.          |   15287.43 |    3631.33
# CICE                 |   18918.76 |     788.28
# Sal. bruts           |       0.00 |   19707.04
# Cotsoc sal           |   19707.04 |   -2719.57
# CSG deduc            |   16987.47 |    -987.47
# Sal. impos.          |       0.00 |   16000.00
# CSG imp. sal.        |   16000.00 |    -464.69
# CRDS sal.            |   15535.31 |     -96.81
# Sal. nets            |       0.00 |   15438.50
# Rev. travail         |       0.00 |   15438.50
# Chômage brut         |   15438.50 |   12500.00
# Chômage decl.        |   15438.50 |   12500.00
# Chômage net          |   15438.50 |   12500.00
# Pensions             |   15438.50 |   12500.00
# Rev. nets            |       0.00 |   27938.50
# Rev. disp.           |       0.00 |   27938.50
